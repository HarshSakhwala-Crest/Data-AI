# %% [markdown]
# # **Creating and Deploying Agents**
# - **Amazon Bedrock Agents** can be created & updated using:
#   - **AWS Management Console**
#   - **Amazon Bedrock APIs**
#   - **AWS CLI & SDKs**
#   - **Infrastructure as Code (IaC)** → AWS CDK, CloudFormation, Terraform

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Build-Time Configuration (Mandatory Parameters)**:
#   - **Foundation Model (FM)** → select the FM to generate responses
#   - **Action Groups** → Defines tasks the agent can execute.
#   - **Knowledge Bases (Optional)** → Enables Retrieval-Augmented Generation (RAG).
#   - **Build-time configuration parameters** - must be defined for an agent to operate.
#   - **AWS Identity and Access management (IAM) Role** → Grants required API permissions for execution.
